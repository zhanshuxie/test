# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
# 生成模拟数据(非线性)
np.random.seed(42)
x = np.linspace(0, 1, 20).reshape(-1, 1)
y_true = np.sin(2*np.pi*x)
y = y_true + np.random.normal(0, 1, x.shape)

# %%
# 构建多项式回归模型
degree = 3
poly_model = make_pipeline(PolynomialFeatures(degree=degree, include_bias=False), LinearRegression())

# %%
# 模型训练
poly_model.fit(x, y)
# Out:
# Pipeline(steps=[('polynomialfeatures',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('linearregression', LinearRegression())])

# %%
# 生成预测数据
x_pred = np.linspace(0, 1, 100).reshape(-1, 1)
y_pred = poly_model.predict(x_pred)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', alpha=0.6, label='原始数据(含噪声)')
plt.plot(x, y_true, color='green', linewidth=2, label='真实函数')
plt.plot(x_pred, y_pred, color='red', linewidth=2, label=f'{degree}次多项式回归拟合')
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title('多项式回归', fontsize=14)
plt.legend(fontsize=10)
plt.legend()

# %%
# 输出模型评分
